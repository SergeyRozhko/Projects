# %% [markdown]
# <h1>Пункты проекта<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Провека-и-приоритизация-гипотез,-проведение-A/B-тестов-и-анализ-результатов" data-toc-modified-id="Провека-и-приоритизация-гипотез,-проведение-A/B-тестов-и-анализ-результатов-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span><center>Провека и приоритизация гипотез, проведение A/B-тестов и анализ результатов</center></a></span></li><li><span><a href="#Задача:
# состоит-в-приоритизации-гипотез-и-проведение-A/B-тестов,-которые-направлены-на-улучшение-показателей-крупного-интернет-магазина." data-toc-modified-id="Задача:
# состоит-в-приоритизации-гипотез-и-проведение-A/B-тестов,-которые-направлены-на-улучшение-показателей-крупного-интернет-магазина.-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span><center>Задача:</center>
# состоит в приоритизации гипотез и проведение A/B-тестов, которые направлены на улучшение показателей крупного интернет-магазина.</a></span></li></ul></li><li><span><a href="#1-ая-часть" data-toc-modified-id="1-ая-часть-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1-ая часть</a></span><ul class="toc-item"><li><span><a href="#План-для-первой-части" data-toc-modified-id="План-для-первой-части-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span><center>План для первой части</center></a></span></li></ul></li><li><span><a href="#Загрузим-данные-и-подготовим-их-к-анализу" data-toc-modified-id="Загрузим-данные-и-подготовим-их-к-анализу-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузим данные и подготовим их к анализу</a></span></li><li><span><a href="#Проведем-работу-по-приоритезации-гипотез-методами:-ICE-и-RICE" data-toc-modified-id="Проведем-работу-по-приоритезации-гипотез-методами:-ICE-и-RICE-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Проведем работу по приоритезации гипотез методами: ICE и RICE</a></span><ul class="toc-item"><li><span><a href="#Метод-ICE" data-toc-modified-id="Метод-ICE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Метод ICE</a></span></li><li><span><a href="#Метод-RICE" data-toc-modified-id="Метод-RICE-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Метод RICE</a></span></li><li><span><a href="#Изменение-приоритизаций-гипотез-и-вывод:" data-toc-modified-id="Изменение-приоритизаций-гипотез-и-вывод:-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Изменение приоритизаций гипотез и вывод:</a></span></li></ul></li><li><span><a href="#2-ая-часть" data-toc-modified-id="2-ая-часть-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>2-ая часть</a></span><ul class="toc-item"><li><span><a href="#План-для-второй-части" data-toc-modified-id="План-для-второй-части-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><center>План для второй части</center></a></span></li><li><span><a href="#Построим-график-кумулятивной-выручки-по-группам" data-toc-modified-id="Построим-график-кумулятивной-выручки-по-группам-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Построим график кумулятивной выручки по группам</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#График-кумулятивного-среднего-чека-по-группам" data-toc-modified-id="График-кумулятивного-среднего-чека-по-группам-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>График кумулятивного среднего чека по группам</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A." data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>График относительного изменения кумулятивного среднего чека группы B к группе A.</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#График-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам" data-toc-modified-id="График-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>График кумулятивного среднего количества заказов на посетителя по группам</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A." data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>График относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Точечный-график-количества-заказов-по-пользователям." data-toc-modified-id="Точечный-график-количества-заказов-по-пользователям.-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Точечный график количества заказов по пользователям.</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя-и-выберим-границу-для-определения-аномальных-пользователей." data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя-и-выберим-границу-для-определения-аномальных-пользователей.-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили количества заказов на пользователя и выберим границу для определения аномальных пользователей.</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.8.1"><span class="toc-item-num">4.8.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Построим-точечный-график-стоимостей-заказов" data-toc-modified-id="Построим-точечный-график-стоимостей-заказов-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Построим точечный график стоимостей заказов</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.9.1"><span class="toc-item-num">4.9.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов-и-выберим-границу-для-определения-аномальных-пользователей" data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов-и-выберим-границу-для-определения-аномальных-пользователей-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили стоимости заказов и выберим границу для определения аномальных пользователей</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.10.1"><span class="toc-item-num">4.10.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.11.1"><span class="toc-item-num">4.11.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-4.12"><span class="toc-item-num">4.12&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.12.1"><span class="toc-item-num">4.12.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-4.13"><span class="toc-item-num">4.13&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.13.1"><span class="toc-item-num">4.13.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-4.14"><span class="toc-item-num">4.14&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.14.1"><span class="toc-item-num">4.14.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Сделаем-промежуточные-выводы:" data-toc-modified-id="Сделаем-промежуточные-выводы:-4.15"><span class="toc-item-num">4.15&nbsp;&nbsp;</span>Сделаем промежуточные выводы:</a></span></li><li><span><a href="#Решение:" data-toc-modified-id="Решение:-4.16"><span class="toc-item-num">4.16&nbsp;&nbsp;</span>Решение:</a></span></li></ul></li></ul></div>

# %% [markdown]
# <h3><center>Провека и приоритизация гипотез, проведение A/B-тестов и анализ результатов</center></h3>
#
# <h3><center>Задача:</center>
# состоит в приоритизации гипотез и проведение A/B-тестов, которые направлены на улучшение показателей крупного интернет-магазина.</h3>

# %% [markdown]
# ## 1-ая часть

# %% [markdown]
# <h3><center>План для первой части</center></h3>
#
# 1. Загрузим данные и подготовим их к анализу
#
# 2. Изучим и проверим данные
#
# 3. Изучим воронку событий
#
# 4. Изучим результаты эксперимента

# %% [markdown]
# ## Загрузим данные и подготовим их к анализу

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats



try:
    data = pd.read_csv('/datasets/hypothesis.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net//datasets/hypothesis.csv')

pd.set_option('display.max_colwidth', None)  

display(data)
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %%
data.rename(columns = {'Hypothesis': 'hypothesis', 'Reach': 'reach', 'Impact': 'impact', 'Confidence': 'confidence', 'Efforts': 'efforts'}, inplace = True)
data.columns

# %%
data['hypothesis'].duplicated().sum() # повторяющихся гипотез нет
# Out:
# 0

# %% [markdown]
# ## Проведем работу по приоритезации гипотез методами: ICE и RICE

# %% [markdown]
# ### Метод ICE

# %%
data['ICE'] = (data['impact'] * data['confidence']) / data['efforts'] # Создаем столбец с оценкой параметров ICE
display(data[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False)) # Сотритруем по убыванию таблицу по столбцу ICE
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Гипотезы с индексом 8, 0 и 7 выглядят наиболее перспективными

# %%
print(data['hypothesis'].loc[[8, 0, 7]]) # Выведем самые перспективные гипотезы по ICE
# Out:
# 8                                               Запустить акцию, дающую скидку на товар в день рождения
# 0    Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7      Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# Name: hypothesis, dtype: object

# %% [markdown]
# ### Метод RICE

# %%
data['RICE'] = (data['reach'] * data['impact'] * data['confidence']) / data['efforts'] # Создаем столбец с оценкой параметров RICE
display(data[['hypothesis', 'RICE']].sort_values(by='RICE', ascending=False)) # Сотритруем по убыванию таблицу по столбцу RICE
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Гипотезы с индексом 7 и 2 выглядят наиболее перспективными

# %%
data['hypothesis'].loc[[7,2]] # Выведем самые перспективные гипотезы по RICE
# Out:
# 7                Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2    Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# Name: hypothesis, dtype: object

# %% [markdown]
# ### Изменение приоритизаций гипотез и вывод:
#
# 1. Отличие методов ICE и RICE состоит в том, что при расчета RICE учитывается фактор Reach, то есть "Охват". Этот фактор предназначен для оценки того, на какое количество людей проект повлияет в течение определенного периода времени, и сколько пользователей увидят такие изменения. Не выгодно тратить время, ресурсы и силы на гипотезу, которая охватывает малое количество пользователей. Проще говоря, в теории изменения будут положительные, но никто их не заменит, поэтому гипотеза с индексом 7 является более перспективной по методу приоритизации RICE.
# 2. Самыми приоритетными гипотезами являются гипотезы с индексами: 7 (Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок) и 0 (Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей).

# %% [markdown]
# ## 2-ая часть

# %% [markdown]
# <h3><center>План для второй части</center></h3>
#
# - Загрузим данные и подготовим их к анализу
#
# - Проанализируем A/B-тест:
#   - Построим график кумулятивной выручки по группам
#   - Построим график кумулятивного среднего чека по группам
#   - Построим график относительного изменения кумулятивного среднего чека группы B к группе A.
#   - Построим график кумулятивного среднего количества заказов на посетителя по группам.
#   - Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.
#   - Построим точечный график количества заказов по пользователям.
#   - Посчитаем 95-й и 99-й перцентили количества заказов на пользователя и выберим границу для определения аномальных пользователей
#   - Построим точечный график стоимостей заказов.
#   - Посчитаем 95-й и 99-й перцентили стоимости заказов и выберим границу для определения аномальных пользователей
#   - Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.
#   - Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.
#   - Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.
#   - Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.
#   - Сделаем промежуточные выводы
#   - Примем решение по результатам теста и обоснуем его

# %%
# Загрузим данные
try:
    orders = pd.read_csv('/datasets/orders.csv')
    visitors = pd.read_csv('/datasets/visitors.csv')
except:
    orders = pd.read_csv('https://code.s3.yandex.net//datasets/orders.csv')
    visitors = pd.read_csv('https://code.s3.yandex.net//datasets/visitors.csv')

pd.set_option('display.max_columns', None)  

display(orders)
display(visitors)
# Out:
#       transactionId   visitorId        date  revenue group
# 0        3667963787  3312258926  2019-08-15     1650     B
# 1        2804400009  3642806036  2019-08-15      730     B
# 2        2961555356  4069496402  2019-08-15      400     A
# 3        3797467345  1196621759  2019-08-15     9759     B
# 4        2282983706  2322279887  2019-08-15     2308     B
# ...             ...         ...         ...      ...   ...
# 1192     2662137336  3733762160  2019-08-14     6490     B
# 1193     2203539145   370388673  2019-08-14     3190     A
# 1194     1807773912   573423106  2019-08-14    10550     A
# 1195     1947021204  1614305549  2019-08-14      100     A
# 1196     3936777065  2108080724  2019-08-15   202740     B
#
# [1197 rows x 5 columns]
#           date group  visitors
# 0   2019-08-01     A       719
# 1   2019-08-02     A       619
# 2   2019-08-03     A       507
# 3   2019-08-04     A       717
# 4   2019-08-05     A       756
# ..         ...   ...       ...
# ...

# %%
# Приведем данные в нужный тип
orders['date'] = orders['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d')
)    

visitors['date'] = visitors['date'].map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d')
)

# %%
# Проверим данные
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   datetime64[ns]
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 46.9+ KB

# %%
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     datetime64[ns]
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
orders['transactionId'].duplicated().sum()
# Out:
# 0

# %%
visitors['date'].duplicated().sum()
# Out:
# 31

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
visitors.duplicated().sum()
# Out:
# 0

# %%
orders[orders['group'] == 'A']['visitorId'].count() # Численность группы А
# Out:
# 557

# %%
orders[orders['group'] == 'B']['visitorId'].count() # Численность группы B
# Видим, что соотношение групп неравное
# Out:
# 640

# %%
old_orders = orders.shape[0]
old_orders # Изначальный объем данных
# Out:
# 1197

# %%
users_a = orders.query('group == "A"') 
users_b = orders.query('group == "B"')

# %%
users_a_b = list(np.intersect1d(users_a['visitorId'], users_b['visitorId']))
len(users_a_b) # 58 пользователей, которые находятся в двух группах
# Out:
# 58

# %%
# удаляем из таблицы orders покупателей, которые входят в обе группы
orders = orders.query('visitorId not in @users_a_b')

# %%
orders.shape[0] # Количество данных после обработки
# Out:
# 1016

# %%
(1 - (orders.shape[0] / old_orders)) *100 
# Так как пользователи, находящиеся в двух группах, могли сделать несколько заказов, нам пришлось отсечь 15% от общего объема данных
# Out:
# 15.121136173767757

# %% [markdown]
# ### Построим график кумулятивной выручки по группам

# %%
# создаем массив уникальных пар значений дат и групп теста
dates_groups = orders[['date','group']].drop_duplicates()

# %%
# Получим строки таблицы orders, дата которых меньше или равна дате элемента из dates_groups, 
# а группа теста равна группе из dates_groups
# Агрегируем значения: вычисляем максимальную дату и максимальные группы, находим число уникальных ID заказов и пользователей. 
orders_aggregated = dates_groups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])]\
.agg({'date' : 'max', 'group' : 'max', 'transactionId' : 'nunique', 'visitorId' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
# Аналогично получим агрегированные кумулятивные по дням данные о посетителях интернет-магазина: 
visitors_aggregated = dates_groups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# %%
# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulative_data = orders_aggregated.merge(visitors_aggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulative_data.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

display(cumulative_data.head(5))
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      23      19   142779       719
# 1 2019-08-01     B      17      17    59758       713
# 2 2019-08-02     A      42      36   234381      1338
# 3 2019-08-02     B      40      39   221801      1294
# 4 2019-08-03     A      66      60   346854      1845

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulative_revenue_group_a = cumulative_data[cumulative_data['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulative_revenue_group_b = cumulative_data[cumulative_data['group']=='B'][['date','revenue', 'orders']]

plt.figure(figsize=(15,5))

# Строим график выручки группы А
plt.plot(cumulative_revenue_group_a['date'], cumulative_revenue_group_a['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulative_revenue_group_b['date'], cumulative_revenue_group_b['revenue'], label='B')


plt.legend() 
plt.title('Графики кумулятивной выручки по дням и группам')
# Out:
# Text(0.5, 1.0, 'Графики кумулятивной выручки по дням и группам')

# %% [markdown]
# #### Вывод:
# 1. Выручка почти равномерно увеличивается в течение всего теста.
# 2. В районе 19 числа наблюдается резкий рост выручки группы "B", а затем все тоже плавное увеличение показателей выручки
# 3. Выручка группы "A" больше чем группы "B" в течение всего теста

# %% [markdown]
# ### График кумулятивного среднего чека по группам

# %%
plt.figure(figsize=(15,5))
plt.plot(cumulative_revenue_group_a['date'], cumulative_revenue_group_a['revenue']/cumulative_revenue_group_a['orders'], label='A')
plt.plot(cumulative_revenue_group_b['date'], cumulative_revenue_group_b['revenue']/cumulative_revenue_group_b['orders'], label='B')
plt.legend()

# %% [markdown]
# #### Вывод:
# 1. Резкий рост среднего чека для группы "B" произошел 19 числа, затем показатель среднего чека для той группы стал снижаться. По всей видимости 19 августа магазин получил огромный заказ/заказы.
# 2. Средний чек для группы "A" после 8 числа стабилен. При этом с первного дня теста по 6 показатель среднего чека для группы "A" снижался, а затем показал умерено сильный рост до 13 числа.
# 3. Средний чек группы "B" "плавал", то есть за ростом показателей шел их спад.

# %% [markdown]
# ### График относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
# собираем данные в одном датафрейме
merged_сumulative_revenue = cumulative_revenue_group_a.merge(cumulative_revenue_group_b, left_on='date', right_on='date', how='left', suffixes=['_a', '_b'])

plt.figure(figsize=(15,5))

# cтроим отношение средних чеков
plt.plot(merged_сumulative_revenue['date'], (merged_сumulative_revenue['revenue_b']/merged_сumulative_revenue['orders_b'])/(merged_сumulative_revenue['revenue_a']/merged_сumulative_revenue['orders_a'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--')

# %% [markdown]
# #### Вывод:
# 1. В нескольких точках графика показатель среднего чека между группами резко «скачет», поэтому в данных есть аномальные значения
# 2. В основном в течение теста показатели группы "B" были лучше второй группы.

# %% [markdown]
# ### График кумулятивного среднего количества заказов на посетителя по группам

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulative_avg_orders_group_a = cumulative_data[cumulative_data['group']=='A'][['date','visitors', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulative_avg_orders_group_b = cumulative_data[cumulative_data['group']=='B'][['date','visitors', 'orders']]

plt.figure(figsize=(15,5))

# Строим график заказов группы А
plt.plot(cumulative_avg_orders_group_a['date'], cumulative_avg_orders_group_a['orders']/cumulative_avg_orders_group_a['visitors'], label='A')

# Строим график заказов группы B
plt.plot(cumulative_avg_orders_group_b['date'], cumulative_avg_orders_group_b['orders']/cumulative_avg_orders_group_b['visitors'], label='B')

plt.legend() 
plt.title('График кумулятивного среднего количества заказов на посетителя по группам')
# Out:
# Text(0.5, 1.0, 'График кумулятивного среднего количества заказов на посетителя по группам')

# %% [markdown]
# #### Вывод:
# 1. В основном во время теста больше заказов сделала группа "B".
# 2. Показатель среднего количества заказов стабилен с 9 августа. До этого числа наблюдается резкий рост и спад показателя среднего количества заказов.

# %% [markdown]
# ### График относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.

# %%
# собираем данные в одном датафрейме
merged_сumulative_avg_orders = cumulative_avg_orders_group_a.merge(cumulative_avg_orders_group_b, left_on='date', right_on='date', how='left', suffixes=['_a', '_b'])

plt.figure(figsize=(15,5))

# cтроим отношение средних чеков
plt.plot(merged_сumulative_avg_orders['date'], (merged_сumulative_avg_orders['orders_b']/merged_сumulative_avg_orders['visitors_b'])/(merged_сumulative_avg_orders['orders_a']/merged_сumulative_avg_orders['visitors_a'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--')

# %% [markdown]
# #### Вывод:
# 1. В среднем показатели среднего количества заказов группы "B" лучше второй группы. При этом в начале теста в основном лучше была группа "А"
# 2. Возможно наличие аномальных показателей среднего количества заказов в обеих группах в течение первой недели теста.

# %% [markdown]
# ### Точечный график количества заказов по пользователям.

# %%
cnt_orders = orders.groupby('visitorId').agg({'transactionId':'count'}).rename(columns={'transactionId': 'orders'}) # получаем датафрэйм с количеством заказов по пользователям

# %%
x_values = pd.Series(range(0, len(cnt_orders['orders']))) # Построим точечную диаграмму

plt.figure(figsize=(15,5))
plt.scatter(x_values, cnt_orders['orders'])

plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.ylabel('Количество заказов', fontsize=12)
plt.title("Точечный график количества заказов по пользователям.", fontsize=10)
plt.grid()
plt.show()

# %% [markdown]
# #### Вывод:
# 1. В основном пользователи делали 1 заказ.
# 2. Есть выбросы в данных. Некоторые пользователи делали больше 8 заказов .

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили количества заказов на пользователя и выберим границу для определения аномальных пользователей.

# %%
print(np.percentile(cnt_orders['orders'], [95, 99])) # Примем за аномальных пользователей тех, кто совершил 3 заказа и более.
# Out:
# [1. 2.]

# %% [markdown]
# #### Вывод:
# 1. Не более 5% пользователей количество заказов больше 2-х и не более чем у 1% покупателей количество заказов больше 4-х
# 2. Примем за аномальных пользователей тех, кто совершил 3 заказа и более.

# %% [markdown]
# ### Построим точечный график стоимостей заказов

# %%
orders.sort_values(by='revenue', ascending=False)
# Out:
#       transactionId   visitorId       date  revenue group
# 425       590470918  1920142716 2019-08-19  1294500     B
# 1196     3936777065  2108080724 2019-08-15   202740     B
# 1136      666610489  1307669133 2019-08-13    92550     A
# 744      3668308183   888512513 2019-08-27    86620     B
# 743      3603576309  4133034833 2019-08-09    67990     A
# ...             ...         ...        ...      ...   ...
# 404      2052514069  1995481842 2019-08-28       70     B
# 933      3760662696  3577713868 2019-08-27       60     B
# 584      1126146019  2705308997 2019-08-20       50     A
# 756       125335873  3423937755 2019-08-30       50     B
# 459       863448794  2738601405 2019-08-19       50     B
#
# [1016 rows x 5 columns]

# %%
x_values = pd.Series(range(0,len(orders['revenue'])))

plt.figure(figsize=(15,5))
plt.scatter(x_values, orders['revenue']) 

plt.xticks(fontsize=15); plt.yticks(fontsize=15)
plt.ylabel('Сумма заказов', fontsize=15)
plt.title('Точечный график стоимостей заказов', fontsize=10)
plt.grid()
plt.show()

# %%
# Уберем пару крайне аномальных значений, чтобы получить корректный результат
sort_orders = orders.query('revenue < 200000') 

x_values = pd.Series(range(0,len(sort_orders['revenue'])))

plt.figure(figsize=(15,5))
plt.scatter(x_values, sort_orders['revenue']) 

plt.xticks(fontsize=15); plt.yticks(fontsize=15)
plt.ylabel('Сумма заказов', fontsize=15)
plt.title('Точечный график стоимостей заказов без нескольких аномальных значений', fontsize=10)
plt.grid()
plt.show()

# %% [markdown]
# #### Вывод:
# 1. Аномальный заказ на сумму 1 294 500 мог исказить данные.
# 2. В основном стоимость заказа не превышала 10 000 руб.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили стоимости заказов и выберим границу для определения аномальных пользователей

# %%
print(np.percentile(orders['revenue'], [95, 99]))
# Out:
# [26785. 53904.]

# %% [markdown]
# #### Вывод:
# 1. Примем за аномальные заказы, те, стоимость которых более 30 000 руб.
# 2. Не более 5% заказов дороже 28 000 рублей и не более 1% дороже 58 233 рублей.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.

# %% [markdown]
# Нулевая гипотеза: различий в среднем количестве заказов на посетителя между группами по «сырым» данным нет.
#
# Альтернативная: различия есть.
#
# Уровень значимости составит 0.05

# %%
# Подготовим данные
visitors_a_daily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitors_a_daily.columns = ['date', 'visitors_per_date_a']

visitors_a_cummulative = visitors_a_daily.apply(
    lambda x: visitors_a_daily[visitors_a_daily['date'] <= x['date']].agg(
        {'date': 'max', 'visitors_per_date_a': 'sum'}
    ),
    axis=1,
)
visitors_a_cummulative.columns = ['date', 'visitors_cummulative_a']

visitors_b_daily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitors_b_daily.columns = ['date', 'visitors_per_date_b']

visitors_b_cummulative = visitors_b_daily.apply(
    lambda x: visitors_b_daily[visitors_b_daily['date'] <= x['date']].agg(
        {'date': 'max', 'visitors_per_date_b': 'sum'}
    ),
    axis=1,
)
visitors_b_cummulative.columns = ['date', 'visitors_cummulative_b']

orders_a_daily = (
    orders[orders['group'] == 'A'][['date', 'transactionId', 'visitorId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionId': pd.Series.nunique, 'revenue': 'sum'})
)
orders_a_daily.columns = ['date', 'orders_per_date_a', 'revenue_per_date_a']

orders_a_cummulative = orders_a_daily.apply(
    lambda x: orders_a_daily[orders_a_daily['date'] <= x['date']].agg(
        {'date': 'max', 'orders_per_date_a': 'sum', 'revenue_per_date_a': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
orders_a_cummulative.columns = [
    'date',
    'orders_cummulative_a',
    'revenue_cummulative_a',
]

orders_b_daily = (
    orders[orders['group'] == 'B'][['date', 'transactionId', 'visitorId', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transactionId': pd.Series.nunique, 'revenue': 'sum'})
)
orders_b_daily.columns = ['date', 'orders_per_date_b', 'revenue_per_date_b']

orders_b_cummulative = orders_b_daily.apply(
    lambda x: orders_b_daily[orders_b_daily['date'] <= x['date']].agg(
        {'date': 'max', 'orders_per_date_b': 'sum', 'revenue_per_date_b': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
orders_b_cummulative.columns = [
    'date',
    'orders_cummulative_b',
    'revenue_cummulative_b',
]

data = (
    orders_a_daily.merge(
        orders_b_daily, left_on='date', right_on='date', how='left'
    )
    .merge(orders_a_cummulative, left_on='date', right_on='date', how='left')
    .merge(orders_b_cummulative, left_on='date', right_on='date', how='left')
    .merge(visitors_a_daily, left_on='date', right_on='date', how='left')
    .merge(visitors_b_daily, left_on='date', right_on='date', how='left')
    .merge(visitors_a_cummulative, left_on='date', right_on='date', how='left')
    .merge(visitors_b_cummulative, left_on='date', right_on='date', how='left')
)

print(data.head(3))
# Out:
#         date  orders_per_date_a  revenue_per_date_a  orders_per_date_b  \
# 0 2019-08-01                 23              142779                 17
# 1 2019-08-02                 19               91602                 23
# 2 2019-08-03                 24              112473                 14
#
#    revenue_per_date_b  orders_cummulative_a  revenue_cummulative_a  \
# 0               59758                    23                 142779
# 1              162043                    42                 234381
# 2               67049                    66                 346854
#
#    orders_cummulative_b  revenue_cummulative_b  visitors_per_date_a  \
# 0                    17                  59758                  719
# 1                    40                 221801                  619
# 2                    54                 288850                  507
#
#    visitors_per_date_b  visitors_cummulative_a  visitors_cummulative_b
# ...

# %%
# Создадим переменные, в которых будет храниться информация о пользователе и его количествах заказов
order_by_user_a = (
    orders[orders['group'] == 'A']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
) 
order_by_user_a.columns = ['user_id', 'orders']

order_by_user_b = (
    orders[orders['group'] == 'B']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
)
order_by_user_b.columns = ['user_id', 'orders']

# %%
# Объявим переменные sample_a и sampleB, в которых пользователям из разных групп будет соответствовать количество заказов. 
# Тем, кто ничего не заказал, будут соответствовать нули.
sample_a = pd.concat([order_by_user_a['orders'],pd.Series(0, index=np.arange(data['visitors_per_date_a'].sum() - len(order_by_user_a['orders'])), name='orders')],axis=0)

sampleB = pd.concat([order_by_user_b['orders'],pd.Series(0, index=np.arange(data['visitors_per_date_b'].sum() - len(order_by_user_b['orders'])), name='orders')],axis=0)

# %%
print("{0:.3f}".format(stats.mannwhitneyu(sample_a, sampleB)[1]))

print("{0:.3f}".format(sampleB.mean() / sample_a.mean() - 1))
# Out:
# 0.011
# 0.160

# %% [markdown]
# #### Вывод:
# 1. p-value (= 0.017) меньше 0.05. Значит нулевую гипотезу отвергаем. Различия в среднем количестве заказов между группами есть
# 2. Относительный прирост среднего количества заказов группы "B" вырос почти на 14%

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.

# %% [markdown]
# Нулевая гипотеза: различий в среднем чеке между группами по «сырым» данным нет.
#
# Альтернативная гипотеза: различия есть.
#
# Уровень значимости составит 0.05

# %%
print('{0:.3f}'.format(stats.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1]))
print('{0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# 0.829
# 0.287

# %% [markdown]
# #### Вывод:
# 1. P-value равно 0,729, что значительно больше 0.05. Значит, причин отвергать нулевую гипотезу нет. Тогда будем считать, что в среднем чеке нет различий
# 2. Относительный прирост среднего чека группы "B" вырос почти на 26%

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b></b>
#
#   1. P-value равно 0,829, что значительно больше 0.05. Значит, причин отвергать нулевую гипотезу нет. Тогда будем считать, что в среднем чеке нет различий
# 2. Что касается прироста среднего чека, то различие в 28% не является статистически значимым, так как нужно проверять информацию по очищенным данным.
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.

# %% [markdown]
# Ранее мы определили, что у аномальмальных пользователей 3 заказа и более, а стоимость одного заказа превышает 30 000 руб.

# %%
users_with_many_orders = pd.concat(
    [
        order_by_user_a[order_by_user_a['orders'] > 3]['user_id'],
        order_by_user_a[order_by_user_a['orders'] > 3]['user_id'],
    ],
    axis=0,
)
users_with_expensive_orders = orders[orders['revenue'] > 30000]['visitorId']
a_b_normal_users = (
    pd.concat([users_with_many_orders, users_with_expensive_orders], axis=0)
    .drop_duplicates()
    .sort_values()
)
print(a_b_normal_users.head(5))
print(a_b_normal_users.shape[0])
# Out:
# 1099    148427295
# 928     204675465
# 684     358944393
# 648     382846391
# 751     689129267
# dtype: int64
# 42

# %% [markdown]
# Всего 55 аномальных пользователей.

# %%
sample_a_filtered = pd.concat(
    [
        order_by_user_a[
            np.logical_not(order_by_user_a['user_id'].isin(a_b_normal_users))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitors_per_date_a'].sum() - len(order_by_user_a['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sample_b_filtered = pd.concat(
    [
        order_by_user_b[
            np.logical_not(order_by_user_b['user_id'].isin(a_b_normal_users))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitors_per_date_b'].sum() - len(order_by_user_b['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %%
# Применим статистический критерий Манна-Уитни к полученным выборкам:
print('{0:.3f}'.format(stats.mannwhitneyu(sample_a_filtered, sample_b_filtered)[1]))
print('{0:.3f}'.format(sample_b_filtered.mean()/sample_a_filtered.mean()-1))
# Out:
# 0.013
# 0.161

# %% [markdown]
# #### Вывод:
# 1. Аномальные показатели почти не повлияли на показатель среднего количества заказов, потому что результаты по среднему количеству заказов практически не изменились. По очищенным данным также можем сказать, что различия в среднем количестве заказов между группами есть.
# 2. Относительный прирос среднего количества заказов группы "B" вырос с 14% до 16%

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
#   p-value практически не изменился. Нулевая гипотеза о том, что различий в среднем количестве заказов нет отвергается. Относительный прирост среднего количества заказов группы "B" вырос на 16%. Показатель является статистически значимым.
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.

# %%
print(
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['visitorId'].isin(a_b_normal_users)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitorId'].isin(a_b_normal_users)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    "{0:.3f}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitorId'].isin(a_b_normal_users)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitorId'].isin(a_b_normal_users)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# 0.842
# -0.031

# %% [markdown]
# #### Вывод:
# 1. P-value увеличился. Значит мы можем быть еще более уверены в том, что различий в среднем чеке между группами нет.
# 2. При этом разница между группами сократилась с 26% до -2%.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#
#   1. В первый пункт стоит добавить, что не отвергаем нулевую гипотезу.
#
#   2. Во второй пункт стоит добавить, что разница в среднем чеке между группами по очищенным данным сократилась с 28% до -3%. Теперь с увереностью можем сказать, что различия не являются статистически значимыми.
# </div>

# %% [markdown]
# ### Сделаем промежуточные выводы:
# 1. Разница в среднем количестве заказов между группами есть. Показатели группы "B" выросли почти на 16%.
# 2. Различий в среднем чеке между группами нет. Тем не менее, стоит отметить, что средний чек группы "B" стал на 2% меньше
# 3. Выручка группы "B" выше второй группы, и она стабильно растет.
# 4. Количество заказов группы "B" значительно увеличилось

# %% [markdown]
# ### Решение:
#
# На основе проведенного анализа можем остановить тест и признать его успешным, потому что группа «B» показала прирос среднего количества заказов. Показатели выросли почти на 16%.
